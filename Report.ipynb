# %% [markdown]
# *Full Name*: John William Braunsdorf
#
# *Email Address*: John.W.Braunsdorf@leidos.com

# %% [markdown]
# # Becoming Familiar

# %% [markdown]
# #### Starter Questions
#
# (one sentence each)
#
# 1. What is a reward function?
# 2. What is an action space?
# 3. What is an RL Algorithm?
# 4. What is the model within an RL algorithm, and how is that model different from the RL algorithm?
# 5. Describe the agent <-> environment interaction loop.

# %% [markdown]
# What is a reward function?
# Rewards are for cars staying in the middle of track and not go out of bounds.
#
# What is an action space?
# Speed and direction with the use of the Camera.
#
# What is an RL Algorithm?
# Uses reward and punishment while data is being processed.
#
# What is the model within an RL algorithm, and how is that model different from the RL algorithm?
# the model is a set of predefined algorithms and the RL algorithms rewards and punishes.
#
# Describe the agent <-> environment interaction loop.
# the agent uses predefined algorithms along with the camera to keeps the model in the middle of the track. The model continues to learn in the loop of a track by the RL algorithms (rewards and punishments)

# %% [markdown]
# #### Question 1
#
# Write a description of this Reinforcement Learning problem and why you feel that it is interesting. Think hard about
# this. Your understanding of the problem is the foundation for your hypothesis formation, subsequent experimentation,
# justification, and analysis. (10 sentence limit)
#
# Examples of Interesting: What will this environment or simulation reveal about the RL algorithm? Is this task going to be easy or
# difficult, how do you define easy or difficult? Are camera sensors a limiting factor, or an advantageous factor, why or
# why not? What is your agent trying to achieve, how will you know when it achieves it or when it does not achieve it?
# Write with depth, ask yourself as many questions as you can, look up information online about what types of questions to
# ask, etc.

# %% [markdown]
# *write your answer for Q1 here*
#
# I have always been facinated by Reinforced learning (RL) as I always joke about making a swam AI cats to roam around my house with Red eyes to scare off. How Elon at Tesla is making his car automous. RL has been very challenging to me with all of the variables needed to get the agent in Sagemaker to perform a simulation. I continue to "want" to my growth in this field and as time past teach others.

# %% [markdown]
# # Initial Exploration and Experimentation

# %% [markdown]
# #### Question 2
#
# Which algorithm did you select and why? (10 sentence limit)

# %% [markdown]
# *Write your answer for Q2 here*
#
# I slected PPO and tweaking various settings in the hyperparamters.

# %% [markdown]
# #### QUESTION 3
#
# Write a hypothesis about your algorithm for its performance and behavior within the environment. Make sure to back up your hypotheses with experimentation and thorough
#    discussion later on. (Check Recipes for success 5 and 6 in the README.md for assistance) (3 sentence limit)

# %% [markdown]
# *Write your answer for Q3 here*
#
# I started out agf=gressive with batch size of 128 and enrotpy of 20 and 30. also each model has been cloned server times without changing the clones. Continued training and keeping in mind of not wasting time past of deminished returns. I do not recall who made this comment, but after 10 hrs I would get deminished returns.

# %% [markdown]
# ## Initial Algorithm Exploration & Experimentation
#
# For your algorithm we would like you to iterate through a range of values two hyperparameters, graph
# the results, analyze and interpret the the behavior of the algorithm. Please make sure the results and subsequent
# analysis you provide are meaningful. Toward this end, in your report please include the following:
#
# #### Graphs
# Create graphs for your algorithm, for each hyperparameter, showing training metrics as a function of episodes.
# `graph_maker.ipynb` can create these for you.
#
# You should have evaluation graphs for reward and distance to center.
#
# #### Analysis
# Analyses of your graphs.
#
# Be creative and think of as many questions you can, and as many answers as you can!
#
# Example, non-exhaustive, list of questions (we are not requiring these questions specifically and only, we do require you to be complete, what you choose to provide in your
# analysis is up to you! We just want to get you going with some starter questions to think about 😄):
#
# - Why did you get the results you did?
# - How long your algorithm take to become optimal and why?
# - What did not result in optimality and why?
# - How did the hyperparameter values effect the performance and why?
# - How much performance was due to the hyperparameters you chose?
# - How do you know your model is the best that it can be, or should be, and why? How do you define best?
# - What did or did not line up with your hypotheses and why?
#
# Please cite any information you use to make your explanations and arguments. See the citation section of the `README.md`
# for more information citations.
#
# Please load a graph then explain it, then repeat until you have explained all of your graphs. For your
# explanations and analysis, there is a 10 sentence limit per graph.

# %% [markdown]
# # DEEP RACER 2024 AI PALOOZA COMPETITION REPORT

# %%
# Load Fig. 1, repeat 

from IPython import display
display.Image("report_images\Mean.png")

# %% [markdown]
# Mean Values: mean values os far less than > 1, when running the report needed to chance value from 1 to 0... 0 represents center line and I felt I accomplished my goal of in creased speed.

# %% [markdown]
# *Analyze and explain graph*

# %%
# Load Fig. 2, repeat
from IPython import display
display.Image("report_images\Median.png")

# %% [markdown]
# Median Values: all my models now have a representation of less then > 1 as stated above. changing the median value from 1 to 0 allowed me to present how my models ran in this second round.

# %%
# Load Fig. 3, repeat
from IPython import display
display.Image("report_images\Standard.png")

# %% [markdown]
# Standard Deviation Value: speen of all my models varied from 3 to 4. also needed to change the standard value from 1 to 0.

# %%
# Load Fig. 4, repeat 
from IPython import display
display.Image("report_images\Rewards.png")

# %% [markdown]
# Reward Values: Rewards are higher for those models traveling at a slower speed and using the default reward functions. Using the standard reward fuction to center line
#
# Action space:
# Speed: [ 1.2 : 4 ] m/s
# Steering angle: [ -30 : 30 ] °

# %% [markdown]
# ## Optimization
#
# 1. Experiment with as many hyperparameters and hyperparameter values as you like, as many reward functions as you
#      like, and whatever action spaces you like until you are satisfied with performance.
# 2. Graph your results, for reward and distance to center, in training graphs and evaluation graphs (the evaluation graph
#    must be over 5 trials). You should have no more than 4 graphs, 2 training and 2 evaluation.
# 3. Analyze, explain, and justify your reward function design and choices, (it's okay if its the default, but a good
#    explanation and justification of the function is still required!). Connect your insights to the problem, to the hypothesis,
#    to the algorithm, to step 2. Be sure to describe why you are satisfied, and justify why you are satisfied.
# 4. Analyze, explain, and justify your action space design and choices. (it's okay if its the default, but a good
#    explanation and justification of the action space is still required!). Connect your insights to the problem, to the
#    hypothesis, to the algorithm, to step 2. Be sure to describe why you are satisfied, and justify why you are satisfied.
# 5. Analyze, explain, and justify your results in your graphs. Connect your insights to the problem, to the hypothesis,
#    to the algorithm, to step 2, anything you can think of. Be sure to describe why you are satisfied, and justify why you are satisfied.
# 6. Create a Grad-CAM image from your trained algorithm.
# 7. Explain the Grad-CAM as a function of your decisions, the algorithm, the reward function, the environment, anything
#    you can think of! Explain everything you can in the image and justify everything you say.
#
# Your experience here is largely the same as Step 2 outside of the evaluation graph and grad CAM, so we are leaving additional instructional text short. If you have any
# questions, please reach out!

# %% [markdown]
# ### Reward Function
#
# (10 sentence limit)
#
# Be sure to explain what behaviors your reward function rewards/punishes and how. Please connect your answer to the
# graphs and analysis you input below. Lastly, *explain, analyze, and justify your reward function in any
# additional way you can think of*

# %%
# Paste reward function code here

def reward_function(params):
    '''
    Example of rewarding the agent to follow center line
    '''
    
    # Read input parameters
    track_width = params['track_width']
    distance_from_center = params['distance_from_center']
    
    # Calculate 3 markers that are at varying distances away from the center line
    marker_1 = 0.1 * track_width
    marker_2 = 0.25 * track_width
    marker_3 = 0.5 * track_width
    
    # Give higher reward if the car is closer to center line and vice versa
    if distance_from_center <= marker_1:
        reward = 1.0
    elif distance_from_center <= marker_2:
        reward = 0.5
    elif distance_from_center <= marker_3:
        reward = 0.1
    else:
        reward = 1e-3  # likely crashed/ close to off track
    
    return float(reward)

# %% [markdown]
# Default Reward fucntion

# %% [markdown]
# *Explain, Analyze, and Justify Reward Function*
#
# The reward function I used was to STAY close to center line. but starter out with a slower speed and gradually maxed out after several hours of training.

# %% [markdown]
# ### Action Space

# %% [markdown]
# (10 sentence limit)
#
# Be sure to mention whether you chose a discrete action space or a continuous action space and why. Be sure to explain
# what hyperparameters did you chose for your action space and why? Please connect your answer to the
# graphs and analysis you input below. Lastly, *explain, analyze, and justify your action
# space in any additional way you can think of*

# %% [markdown]
# # Front Facing Cam - This cell opens the model metadata for your inspections
# {
#     "action_space": {
#         "speed": {
#             "high": 4,
#             "low": 1.2
#         },
#         "steering_angle": {
#             "high": 30,
#             "low": -30
#         }
#     },
#     "action_space_type": "continuous",
#     "neural_network": "DEEP_CONVOLUTIONAL_NETWORK_SHALLOW",
#     "preprocess_type": "GREY_SCALE",
#     "regional_parameters": [
#         "0",
#         "0",
#         "0",
#         "0"
#     ],
#     "sensor": [
#         "STEREO_CAMERAS"
#     ],
#     "training_algorithm": "clipped_ppo",
#     "version": "5"
# }

# %% [markdown]
# Standards steetings, except for low speed for the corners of 1.2 and max speed of 3.0 straights

# %% [markdown]
# ### Training and Evaluation Graphs
#
# 10 sentence limit per graph explanation

# %%
# Load Fig. N
from IPython import display
display.Image("report_images\wypnt.png")

# %% [markdown]
# the 2024 American Hills speed track and with this track there is over 223 point

# %% [markdown]
# *Analyze and explain graph*

# %%
# Load Fig. N+1, repeat
from IPython import display
display.Image("report_images/rewards1.png")

# %% [markdown]
# ### Grad Cam Image
# Grad-cam is an explainability tool that can give you insight into what your model cares about.
#
# What do the grad-cam images tell you about what information your model used to select its actions, the reward function,
# any choices that you made, etc?

# %%
# Paste Grad-CAM image here
# Heat Map "iteration" 1
from IPython import display
display.Image("report_images/iteration1.png")

# %% [markdown]
# *Explain Grad-CAM image here*
#
# after several clones and successful passes on the track and stayed within the the boarders.

# %% [markdown]
# ### Additional Questions

# %% [markdown]
# What hyperparameters did you select for change and why? How did you change them and why?

# %% [markdown]
# # Hyperparameter                    Value
# Gradient descent batch size         128
# Entropy                             .30
# Discount factor                     0.999
# Loss type                           Huber
# Learning rate                       0.0010
# Number of experience episodes between each policy-updating iteration
# 10
# Number of epochs
# 10
#
# I wanted to mix things up and use larger chunks of data for RL. in this case I felt it worked for me.

# %% [markdown]
# From your evaluation run, paste a screenshot of your model's time around the track for all 5 trials

# %%
# Load screenshot here
from IPython import display
display.Image("report_images/evalrun1.PNG")

# %% [markdown]
# the above track used an entropy of 30

# %%
from IPython import display
display.Image("report_images/evalrun2.PNG")

# %% [markdown]
# the above track used an entropy of 25

# %%
from IPython import display
display.Image("report_images/evalrun3.PNG")

# %% [markdown]
# the above track used an entropy of 20

# %% [markdown]
# #### Question 4
#
# (10 sentence limit)
#
# List/graph any other metrics you feel are important for your model and provide an explanation of why you think your model got those results.

# %% [markdown]
# *Write answer to Question 13 here*

# %%
# load screen shots

# episode 1
from IPython import display
display.Image("report_images/episode1.png")

# %%
# episode 2 
from IPython import display
display.Image("report_images/episode2.png")

# %%
# Iteration Behavior 1
from IPython import display
display.Image("report_images/iteration1behavior.png")

# %%
# Iteration Behavior 2
from IPython import display
display.Image("report_images/iteration2behavior.png")

# %%
# Iteration Behavior 3
from IPython import display
display.Image("report_images/iteration3behavior.png")

# %% [markdown]
# ## Ethical Considerations

# %% [markdown]
# #### Question 5
# (10 sentence limit for each requirement)
#
# What are the ethical considerations / problems of your self-driving vehicle, based on the results achieved in your
# optimization step, if it were deployed onto a city street tomorrow and required to follow the four requirement below?
# Provide considerations for each requirement.
#
# City Street deployment requirements:
# 1. pedestrians cannot be hit, even at the expense of the vehicle occupant.
# 2. vehicle MUST (hint: absolute guarantee, no probability) stay within the road
# 3. All vehicle decisions must be audited and fully "explainable"
# 4. vehicle driving must be "stable"

# %% [markdown]
# Look no further than the Tesla self-driving program Elon Musk is using. tesla uses its own CPU\OS\storage\cameras\sensors\global GPS and many other factors which would answers the above questions and no one person gets injured

# %% [markdown]
# #### Question 6
#
# (10 sentence limit for each mitigation, 5 sentence minimum)
#
# How will you solve the ethical considerations / problems you described in Question 5?

# %% [markdown]
# Ethical - for me its to make sure no one person ever gets injured and is always safe. Keep in mind Tesla does NOT patten and allows free market to enhance his vision of the future. Sames as space travel with SpaceX and return landing.

# %% [markdown]
# #### Question X
#
# (10 sentence limit, 5 sentence minimum)
#
# Would your model hurt anyone? Why or why not?
#
# in a controlled area, no one should ever be injured and with RL the car will eventually be self driving. but I do think we are years from that happening.

# %% [markdown]
# #### Question X
#
# (10 sentence limit, 5 sentence minimum)
#
# Does your model violate any protected classes? Why or why not? (link to protected classes in U.S. on wikipedia)

# %% [markdown]
# # Contemplative Reflection

# %% [markdown]
# #### Question 7
#
# (10 sentence limit, 5 sentence minimum)
#
# Summarize your results as you would to the customer and explain what they mean for the company.

# %% [markdown]
# *write your answer for Question 7 here*
#
# I realize I could have made my results better with a faster speeds in the turns. current speeds are 1.2 and could have been changed to 2.0 to 2.5 and several training.

# %% [markdown]
# #### Question 8
#
# (10 sentence limit, 5 sentence minimum)
#
#
# What are the tradeoffs between speed and stability?  How did you handle these tradeoffs?

# %% [markdown]
# *write your answer for Question 8 here*
#
# In the beginning I started off conversative with sloswers speeds in the turns and in the end game me good over all results. But realized I ould have incereased speeds to 2.0 to 2.5 and several training

# %% [markdown]
# #### Question 9
#
# (10 sentence limit, 5 sentence minimum)
#
# What were some of the things you struggled with?  Were you able to overcome them?  How?

# %% [markdown]
# *write your answer for Question 9 here*

# %% [markdown]
# #### Question 10
#
# (10 sentence limit, 5 sentence minimum)
#
# What were some things you tried that didn't work?  Why do you think they were unsuccessful?  What did you learn?

# %% [markdown]
# *write your answer for Question 10 here*
#
# I tried to change the speeds points with more than two steering angles of 30(-|+) degrees and I am sure with more training it could have worked out. but in my case it down not

# %% [markdown]
# #### Question 11
#
# (10 sentence limit, 5 sentence minimum)
#
# If you had more time or could start again, what might you do differently?

# %% [markdown]
# *write your answer for Question 11 here*
#
# I would continue to train my best results and increase the speeds at lower end from 1.2 to 2.0 to 2.5 and leaving the top end speed at 4.0. I think I would have concenetrated more on the zig-zag rewards too.

# %% [markdown]
# #### Question 12
#
# (10 sentence limit, 5 sentence minimum)
#
# What did you think of requirement 1 in Question 5?

# %% [markdown]
# *write your answer for Question 12 here*
#
# in the beginning I truly did not understand. but the more I trained and read about each option with Hyperperameters, steering angles and rewards.

# %% [markdown]
# ## BONUS - RELATED WORKS

# %% [markdown]
# **QUESTION 13**
#
# You will suggest improvements to your algorithm through the lense of what you have empirically discovered and
# determined. You do not have to create or invent these improvements.  Both PPO and SAC have been analyzed and discussed
# thoroughly within the scientific community. Your job is to use your findings to guide your research online, find
# papers with your improvements discussed, and provide your commentary on the improvements. Specifically, provide your
# own interpretation of the improvements by discussing the methods, the experiments, and the results of the authors. We
# will assign you meaningful extra credit for completing this optional section.
#
# Read 1-3 scientific papers following the above guidance and provide a 5 sentences minimum, 10
# sentences maximum on how the technique works, and how it might be used to improve your model's performance, based on
# your own observations from your report.  You can use
# Arxiv, Google Scholar, or Semantic Scholar (❤️) to search for resources, as well as repositories like this one
# https://github.com/yingchengyang/Reinforcement-Learning-Papers

# %% [markdown]
# **BONUS PAPER 1**

# %% [markdown]
# https://d1wqtxts1xzle7.cloudfront.net/83530830/IRJET-V3I969-libre.pdf?1649484647=&response-content-disposition=inline%3B+filename%3DTesla_Autopilot_Semi_Autonomous_Driving.pdf&Expires=1725380820&Signature=QmV~kLsPrlwKrpVIcP6YW2WlnA1KBOU7rYho1rq3Eu4j4UoRYtYYf2L21FV2m1sj0OBZB05f-fLJ~BF97Sriogn5mJer53F~Y3cgx06iDcJmzkysTb3nAu6asQkGx0VTspmRmE8Le4uv4GHeylhIYaptOe49Ut0WQ~VFlge4Cp8O6WjE8oe5Yfq~rDcBFV0BgzAGR6wjsdHvHnf6vuYu5vv8l4dRrP1wX~bslAxVkDSHls4gF3FRgDly5uZYkfGbd-5qf-WmizefGFj7Rfi~hKQcHvzt7PEcCxZiX40o0qx~fG4hMGFBYaBVbdyGLktAm1vZTlTDd~4DxCjWUeoU4g__&Key-Pair-Id=APKAJLOHF5GGSLRBV4ZA
#
# the tesla autopolit is very impressive, but still has some glaring issues with unable to detect lanes and still objects like humans. I would consider this a big issue. in the end tesla still recommends that drivers stay in control and becareful when in "autopilot" mode. Tesla having 12 points on a car to collect data. autonomous driving still needs more data. it will be a matter of time, sim2real and human interaction to Eventually lead Tesla RL model to be successful and so the question renames, will car ever be 100% autonomous?

# %% [markdown]
# **BONUS PAPER 2**

# %% [markdown]
# Human-level control through deep reinforcement learning
# https://www.nature.com/articles/nature14236
#
# Reinforced learning is deeply rooted in psychological and neuroscientific. The perspective of being able to solve complex problems like human and animals. The brain can retain so much data. Its a matter of time until humans can access and prcess like a machine. with the access of the deep Q-network and inputs which make RL successful. This article also point out how the agent was able to interact with an Atari 2600 and its games and be successful.

# %% [markdown]
# **BONUS PAPER 3**

# %% [markdown]
# Animals and AI. The role of animals in AI research and application – An overview and ethical evaluation
#
# https://www.sciencedirect.com/science/article/pii/S0160791X21001536
#
# Article dicusses how AI and humanity are developing at a fast rate. Using Animals and its brain structure, also considering the ethical stand point of how some researchers consider animals \animal brains simply no more than live stock and NOT a living being. Ethically we need to draw a line with development. Moreover, morally can we do this, but we should be asking "should we do this" and treat other living beings as lesser than humans. Ethical issues arise and do we have a moral compass to respect another living beings.
